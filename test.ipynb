# %%
import numpy as np

n_values = np.unique(np.logspace(0, 3, 22, dtype=int)) # 20 values from 1 to 1000 on a log scale
print(n_values)
# Out:
# [   1    2    3    5    7   10   13   19   26   37   51   71  100  138
#   193  268  372  517  719 1000]
